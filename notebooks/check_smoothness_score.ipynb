# %%
import sys
sys.path.insert(1, '/Users/nityaravi/Documents/GitHub/RotationCurves/')
from mapSmoothness_functions import how_smooth

sys.path.insert(1, '/Users/nityaravi/Documents/GitHub/RotationCurves/spirals/')

from DRP_rotation_curve import extract_data

import numpy as np
import numpy.ma as ma
from astropy.io import fits
import matplotlib.pyplot as plt
from astropy.table import Table

# %%
DRP_FOLDER = '/Users/nityaravi/Documents/Research/RotationCurves/data/manga/DR17/'

# %%
gals = ['8951-3704', '12079-9101', '11835-6103', '11835-12703', '11024-6102', '11955-3703']

# %%
gal_ID = gals[0]

maps = extract_data(DRP_FOLDER, gal_ID, ['Ha_vel', 'Ha_flux'])

map_smoothness = how_smooth(maps['Ha_vel'], maps['Ha_vel_mask'])
map_smoothness_5sigma = how_smooth(maps['Ha_vel'],
                                   np.logical_or(maps['Ha_vel_mask'] > 0,
                                                 np.abs(maps['Ha_flux']*np.sqrt(maps['Ha_flux_ivar'])) < 5))

print(gal_ID)
print('smoothness score: ', map_smoothness)
print('smoothness score 5sigma: ', map_smoothness_5sigma)

plt.imshow(ma.array(maps['Ha_vel'], mask=
                                   np.logical_or(maps['Ha_vel_mask'] > 0,
                                                 np.abs(maps['Ha_flux']*np.sqrt(maps['Ha_flux_ivar'])) < 5)))
# Out:
# 8951-3704
# smoothness score:  2.3840980037213058
# smoothness score 5sigma:  0.0

# %%
gal_ID = gals[1]

maps = extract_data(DRP_FOLDER, gal_ID, ['Ha_vel', 'Ha_flux'])

map_smoothness = how_smooth(maps['Ha_vel'], maps['Ha_vel_mask'])
map_smoothness_5sigma = how_smooth(maps['Ha_vel'],
                                   np.logical_or(maps['Ha_vel_mask'] > 0,
                                                 np.abs(maps['Ha_flux']*np.sqrt(maps['Ha_flux_ivar'])) < 5))

print(gal_ID)
print('smoothness score: ', map_smoothness)
print('smoothness score 5sigma: ', map_smoothness_5sigma)

plt.imshow(ma.array(maps['Ha_vel'], mask=
                                   np.logical_or(maps['Ha_vel_mask'] > 0,
                                                 np.abs(maps['Ha_flux']*np.sqrt(maps['Ha_flux_ivar'])) < 5)))
# Out:
# 12079-9101
# smoothness score:  0.9595410692822802
# smoothness score 5sigma:  0.5503718476367048

# %%
gal_ID = gals[2]

maps = extract_data(DRP_FOLDER, gal_ID, ['Ha_vel', 'Ha_flux'])

map_smoothness = how_smooth(maps['Ha_vel'], maps['Ha_vel_mask'])
map_smoothness_5sigma = how_smooth(maps['Ha_vel'],
                                   np.logical_or(maps['Ha_vel_mask'] > 0,
                                                 np.abs(maps['Ha_flux']*np.sqrt(maps['Ha_flux_ivar'])) < 5))

print(gal_ID)
print('smoothness score: ', map_smoothness)
print('smoothness score 5sigma: ', map_smoothness_5sigma)

plt.imshow(ma.array(maps['Ha_vel'], mask=
                                   np.logical_or(maps['Ha_vel_mask'] > 0,
                                                 np.abs(maps['Ha_flux']*np.sqrt(maps['Ha_flux_ivar'])) < 5)))
# Out:
# 11835-6103
# smoothness score:  2.6805607539670477
# smoothness score 5sigma:  nan

# %%
gal_ID = gals[3]

maps = extract_data(DRP_FOLDER, gal_ID, ['Ha_vel', 'Ha_flux'])

map_smoothness = how_smooth(maps['Ha_vel'], maps['Ha_vel_mask'])
map_smoothness_5sigma = how_smooth(maps['Ha_vel'],
                                   np.logical_or(maps['Ha_vel_mask'] > 0,
                                                 np.abs(maps['Ha_flux']*np.sqrt(maps['Ha_flux_ivar'])) < 5))

print(gal_ID)
print('smoothness score: ', map_smoothness)
print('smoothness score 5sigma: ', map_smoothness_5sigma)

plt.imshow(ma.array(maps['Ha_vel'], mask=
                                   np.logical_or(maps['Ha_vel_mask'] > 0,
                                                 np.abs(maps['Ha_flux']*np.sqrt(maps['Ha_flux_ivar'])) < 5)))
# Out:
# 11835-12703
# smoothness score:  2.3972928010167216
# smoothness score 5sigma:  0.6539408365885416

# %%
gal_ID = gals[4]

maps = extract_data(DRP_FOLDER, gal_ID, ['Ha_vel', 'Ha_flux'])

map_smoothness = how_smooth(maps['Ha_vel'], maps['Ha_vel_mask'])
map_smoothness_5sigma = how_smooth(maps['Ha_vel'],
                                   np.logical_or(maps['Ha_vel_mask'] > 0,
                                                 np.abs(maps['Ha_flux']*np.sqrt(maps['Ha_flux_ivar'])) < 5))

print(gal_ID)
print('smoothness score: ', map_smoothness)
print('smoothness score 5sigma: ', map_smoothness_5sigma)

plt.imshow(ma.array(maps['Ha_vel'], mask=
                                   np.logical_or(maps['Ha_vel_mask'] > 0,
                                                 np.abs(maps['Ha_flux']*np.sqrt(maps['Ha_flux_ivar'])) < 5)))
# Out:
# 11024-6102
# smoothness score:  2.1291793993595496
# smoothness score 5sigma:  0.3963538408279419

# %%
gal_ID = gals[5]

maps = extract_data(DRP_FOLDER, gal_ID, ['Ha_vel', 'Ha_flux'])

map_smoothness = how_smooth(maps['Ha_vel'], maps['Ha_vel_mask'])
map_smoothness_5sigma = how_smooth(maps['Ha_vel'],
                                   np.logical_or(maps['Ha_vel_mask'] > 0,
                                                 np.abs(maps['Ha_flux']*np.sqrt(maps['Ha_flux_ivar'])) < 5))

print(gal_ID)
print('smoothness score: ', map_smoothness)
print('smoothness score 5sigma: ', map_smoothness_5sigma)

plt.imshow(ma.array(maps['Ha_vel'], mask=
                                   np.logical_or(maps['Ha_vel_mask'] > 0,
                                                 np.abs(maps['Ha_flux']*np.sqrt(maps['Ha_flux_ivar'])) < 5)))
# Out:
# 11955-3703
# smoothness score:  0.6552914577872152
# smoothness score 5sigma:  0.6271548045952471

# %%
gal_ID = '8335-12704'

maps = extract_data(DRP_FOLDER, gal_ID, ['Ha_vel', 'Ha_flux'])

plt.hist(maps['Ha_vel'].flat, bins=np.arange(np.min(maps['Ha_vel']), np.max(maps['Ha_vel']), 5))
plt.ylim(0,100)
# Out:
# (0.0, 100.0)

# %%
t = Table.read('/Users/nityaravi/Documents/Research/DESI/PV/TF/Y1/Y1_PV_TF_MaNGA_match.fits')

# %%
8951-3704, 11835-6103, 11024-6102

# %%
t[t['plateifu'] == '11024-6102']
# Out:
# <Table length=1>
# plate ifudsgn  plateifu  ... Vfit_corr_0p4R26 Vfit_corr_0p4R26_err
# int64  int64   bytes11   ...     float64            float64
# ----- ------- ---------- ... ---------------- --------------------
# 11024    6102 11024-6102 ...               --                   --
