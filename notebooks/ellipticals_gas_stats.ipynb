# %%
from astropy.table import Table
import numpy as np
import matplotlib.pyplot as plt

# %%
master_table_fn = '/Users/nityaravi/Documents/Research/RotationCurves/data/manga/output_files/DR17/CURRENT_MASTER_TABLE/Elliptical_sphdisk_refitspirals_BPT_v6.fits'
master_table = Table.read(master_table_fn)

# %%
master_table[:5]
# Out:
# <Table length=5>
# plate ifudsgn   plateifu  ... BPT_class sum_M_star_0p1_R90 count_M_star_0p1_R90
# int64 bytes32   bytes32   ...  float64       float64             float64
# ----- ------- ----------- ... --------- ------------------ --------------------
# 10001   12701 10001-12701 ...       0.0                0.0                  0.0
# 10001   12702 10001-12702 ...       0.0                0.0                  0.0
# 10001   12703 10001-12703 ...       0.0                0.0                  0.0
# 10001   12704 10001-12704 ...       0.0                0.0                  0.0
# 10001   12705 10001-12705 ...       0.0                0.0                  0.0

# %%
ellipticals = master_table[master_table['Mvir'] > 0]
ellipticals = ellipticals[ellipticals['sphd_M_star'] > 0]

# %%
ellipticals_HI = ellipticals[ellipticals['logHI']>0]
ellipticals_HI_lim = ellipticals[ellipticals['logHIlim']>0]

# %%
plt.hist(10**(ellipticals_HI['logHI']-ellipticals_HI['sphd_M_star']))
# plt.hist(ellipticals_HI_lim['logHIlim'], alpha=0.2)
# Out:
# (array([70., 17.,  2.,  3.,  3.,  3.,  2.,  0.,  0.,  2.]),
#  array([7.20046657e-04, 1.12180880e-01, 2.23641713e-01, 3.35102546e-01,
#         4.46563380e-01, 5.58024213e-01, 6.69485046e-01, 7.80945879e-01,
#         8.92406713e-01, 1.00386755e+00, 1.11532838e+00]),
#  <BarContainer object of 10 artists>)

# %%
len(ellipticals_HI)
# Out:
# 102

# %%
len(ellipticals_HI_lim)
# Out:
# 838

# %%
len(ellipticals)
# Out:
# 2460

# %%
plt.hist(10**(ellipticals['logH2'][ellipticals['logH2']>0]-ellipticals['sphd_M_star'][ellipticals['logH2']>0]))
# Out:
# (array([1., 1., 0., 0., 0., 0., 0., 1., 0., 1.]),
#  array([0.01137761, 0.0123669 , 0.01335619, 0.01434548, 0.01533477,
#         0.01632406, 0.01731335, 0.01830263, 0.01929192, 0.02028121,
#         0.0212705 ]),
#  <BarContainer object of 10 artists>)

# %%
mascot_fn = '/Users/nityaravi/Documents/Research/RotationCurves/data/manga/MASCOT.fits'
mascot = Table.read(mascot_fn)
mascot[:5]
# Out:
# WARNING: UnitsWarning: 'log(msun)' did not parse as fits unit: At col 4, Unit 'msun' not supported by the FITS standard. Did you mean Sun? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# WARNING: UnitsWarning: 'log(msun/yr)' did not parse as fits unit: At col 4, Unit 'msun' not supported by the FITS standard. Did you mean Sun? If this is meant to be a custom unit, define it with 'u.def_unit'. To have it recognized inside a file reader or other code, enable it with 'u.add_enabled_units'. For details, see https://docs.astropy.org/en/latest/units/combining_and_defining.html [astropy.units.core]
# <Table length=5>
#                                                             MaNGA ID                                                             ...
# ...

# %%
plt.hist(mascot['log(H2_mass)'])
# Out:
# (array([ 5., 14., 22., 46., 37., 32., 17., 11.,  1.,  2.]),
#  array([ 8.3517744 ,  8.58219507,  8.81261574,  9.04303641,  9.27345708,
#          9.50387774,  9.73429841,  9.96471908, 10.19513975, 10.42556041,
#         10.65598108]),
#  <BarContainer object of 10 artists>)

# %%
ellipticals[ellipticals['logH2_CG']>0]
# Out:
# <Table length=0>
# plate ifudsgn plateifu ... BPT_class sum_M_star_0p1_R90 count_M_star_0p1_R90
# int64 bytes32 bytes32  ...  float64       float64             float64
# ----- ------- -------- ... --------- ------------------ --------------------

# %%
ellipticals[ellipticals['logH2_M']>0]
# Out:
# <Table length=4>
# plate ifudsgn  plateifu ... BPT_class sum_M_star_0p1_R90 count_M_star_0p1_R90
# int64 bytes32  bytes32  ...  float64       float64             float64
# ----- ------- --------- ... --------- ------------------ --------------------
#  8244    3701 8244-3701 ...       2.0 10.205650564870302                 37.0
#  8440    6104 8440-6104 ...       0.0 10.075674777374315                 37.0
#  8553    1901 8553-1901 ...       0.0  9.134973526000977                  1.0
#  8595    6104 8595-6104 ...       1.0  10.67755467240833                 65.0
