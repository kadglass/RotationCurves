# %%
import astropy.io.fits as fits
import numpy as np
import matplotlib.pyplot as plt
from astropy.table import Table

# %%
hdu = fits.open('/Users/nityaravi/Documents/Research/RotationCurves/data/manga/manga_firefly-v2_4_3-STELLARPOP.fits')

# %%
vcell = hdu[4].data[0]
spax = hdu[5].data[0]
mass = hdu[11].data[0]

# %%
mass.shape
# Out:
# (2800, 2)

# %%
for i in range(2800):
    plt.scatter(vcell[i][1], vcell[i][2], c=mass[i][0])
    
plt.xlim(-5,5)
plt.ylim(-5,5)
# Out:
# (-5.0, 5.0)
