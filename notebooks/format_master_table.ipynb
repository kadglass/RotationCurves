# %%
from astropy.table import Table
import numpy as np
from astropy.io import fits

# %% [markdown]
# Start with DRPall disk/H alpha fits and NSA and create master table columns

# %%
FOLDER = '/Users/nityaravi/Documents/Research/RotationCurves/data'
disk_fn = FOLDER + '/manga/output_files/DR17/H_alpha_HIvel_BB.fits'
NSA_fn = FOLDER + '/nsa_v1_0_1.fits'

# %%
d = Table.read(disk_fn, format='fits')
n = Table.read(NSA_fn, format='fits')

# %%
d
# Out:
# <Table length=11273>
# plate ifudsgn   plateifu  ...       M_R90            M_R90_err      fit_function
# int64 bytes32   bytes32   ...      float64            float64         float64
# ----- ------- ----------- ... ------------------ ------------------ ------------
# 10001   12701 10001-12701 ... 10.637055736445056  9.856536145016422          0.0
# 10001   12702 10001-12702 ... 10.600037009816079  10.15080355502181          0.0
# 10001   12703 10001-12703 ...  11.32307263875663 10.727979027247507          0.0
# 10001   12704 10001-12704 ...  10.37352631137793   9.51492042443341          0.0
# 10001   12705 10001-12705 ... 11.635990412349255  10.81301448064697          0.0
# 10001    1901  10001-1901 ... 10.029728499104738  9.289068572860335          0.0
# 10001    1902  10001-1902 ...                 --                 --           --
# 10001    3701  10001-3701 ...                 --                 --           --
# ...

# %%
# master table columns
cols = ['MaNGA_plate', 'MaNGA_IFU', 'NSA_plate', 'NSA_fiberID', 'NSA_MJD', 'NSA_index', 
        'NSA_ID', 'NSA_RA', 'NSA_DEC', 'NSA_ba', 'NSA_phi', 'NSA_redshift', 'NSA_Mstar',
        'vflag', 'BPT', 'index', 'u_r', 'smoothness_score', 'ba_map', 'ba_err_map', 'phi_map', 'phi_err_map',
        'Vsys_map', 'Vsys_err_map', 'x0_map', 'x0_err_map', 'y0_map', 'y0_err_map',
        'Vmax_map', 'Vmax_err_map', 'alpha_map', 'alpha_err_map', 'Rturn_map', 'Rturn_err_map',
        'M90_map', 'M90_err_map', 'M3p5_map', 'M3p5_err_map', 'rho_bulge_map', 'rho_bulge_err_map',
        'R_bulge_map', 'R_bulge_err_map', 'Sigma_disk_map', 'Sigma_disk_err_map', 'Rdisk_map',
        'Rdisk_err_map', 'M90_disk_map', 'M90_disk_err_map', 'M3p5_disk_map', 'M3p5_disk_err_map',
        'NSA_elpetro_th90', 'chi2_map', 'chi2_disk_map', 'logHI', 'logHI200kms', 'WF50', 'WF50_err',
        'CMD_class', 'map_fit_flag', 'imc', 'aimc', 'cd', 'DL_ttype', 'R90']

# %%
MaNGA_plate = np.array(d['plate'], dtype=int)
MaNGA_IFU = np.array(d['ifudsgn'], dtype=int)
NSA_ID = np.array(d['nsa_nsaid'], dtype=int)
NSA_ba = np.array(d['nsa_elpetro_ba'], dtype=float)
NSA_phi = np.array(d['nsa_elpetro_phi'], dtype=float)
NSA_redshift = np.array(d['nsa_z'], dtype=float)
NSA_Mstar = np.array(d['nsa_elpetro_mass'], dtype=float)
smoothness_score = np.array(d['smoothness_score'], dtype=float)
ba_map = np.array(d['ba'], dtype=float)
ba_err_map = np.array(d['ba_err'], dtype=float)
phi_map = np.array(d['phi'], dtype=float)
phi_err_map = np.array(d['phi_err'], dtype=float)
Vsys_map = np.array(d['v_sys'], dtype=float)
Vsys_err_map = np.array(d['v_sys_err'], dtype=float)
x0_map = np.array(d['x0'], dtype=float)
x0_err_map = np.array(d['x0_err'], dtype=float)
y0_map = np.array(d['y0'], dtype=float)
y0_err_map = np.array(d['y0_err'], dtype=float)
Vmax_map = np.array(d['v_max'], dtype=float)
Vmax_err_map = np.array(d['v_max_err'], dtype=float)
alpha_map = np.array(d['alpha'], dtype = float)
alpha_err_map = np.array(d['alpha_err'], dtype=float)
Rturn_map = np.array(d['r_turn'], dtype=float)
Rturn_err_map = np.array(d['r_turn_err'], dtype=float)
M90_map = np.array(d['M_R90'], dtype=float)
M90_err_map = np.array(d['M_R90_err'], dtype=float)
M3p5_map = np.array(d['M'], dtype=float)
M3p5_err_map = np.array(d['M_err'], dtype=float)
rho_bulge_map = np.array(d['rho_bulge'], dtype=float)
rho_bulge_err_map = np.array(d['rho_bulge_err'], dtype=float)
R_bulge_map = np.array(d['R_bulge'], dtype=float)
R_bulge_err_map = np.array(d['R_bulge_err'], dtype=float)
Sigma_disk_map = np.array(d['Sigma_disk'], dtype=float)
Sigma_disk_err_map = np.array(d['Sigma_disk_err'], dtype=float)
Rdisk_map = np.array(d['R_disk'], dtype=float)
Rdisk_err_map = np.array(d['R_disk_err'], dtype=float)
M90_disk_map = np.array(d['M90_disk'], dtype=float)
M90_disk_err_map = np.array(d['M90_disk_err'], dtype=float)
M3p5_disk_map = np.array(d['M_disk'], dtype=float)
M3p5_disk_err_map = np.array(d['M_disk_err'], dtype=float)
NSA_elpetro_th90 = np.array(d['nsa_elpetro_th90'], dtype=float)
chi2_map = np.array(d['chi2'], dtype=float)
chi2_disk_map = np.array(d['chi2_disk'], dtype=float)
logHI = np.array(d['logHI'], dtype=float)
logHI200kms = np.array(d['logHIlim'], dtype=float)
WF50 = np.array(d['WF50'], dtype=float)
WF50_err = np.array(d['WF50_err'], dtype=float)
map_fit_flag = np.array(d['fit_flag'], dtype=float)
DL_ttype = np.array(d['DL_ttype'], dtype=float)

# %%
NSA_ind = {}

for i in range(len(n)):
    NSA_I = n['NSAID'][i]

    NSA_ind[NSA_I] = i

# %%
NSA_index = np.ones(len(d))*np.nan
NSA_index.fill(-9999)
for i in range(0, len(d)):
    if d['nsa_nsaid'][i] >= 0:
        NSA_index[i] = np.array(NSA_ind[d['nsa_nsaid'][i]], dtype=int)

# %%
NSA_plate = np.ones(len(d))*np.nan
NSA_fiberID = np.ones(len(d))*np.nan
NSA_MJD = np.ones(len(d))*np.nan
NSA_RA = np.ones(len(d))*np.nan
NSA_DEC = np.ones(len(d))*np.nan

for i in range(0, len(d)):
    
    if NSA_index[i] >= 0:
    
        NSA_plate[i] = n['PLATE'][int(NSA_index[i])]
        NSA_fiberID[i] = n['FIBERID'][int(NSA_index[i])]
        NSA_MJD[i] = n['MJD'][int(NSA_index[i])]
        NSA_RA[i] = n['RA'][int(NSA_index[i])]
        NSA_DEC[i] = n['DEC'][int(NSA_index[i])]

# %%
NSA_index = np.array(NSA_index, dtype=int)
NSA_index
# Out:
# array([ 48157,  48188,  55648, ..., 294374, 294459, 550782])

# %%
col1 = fits.Column(name='MaNGA_plate', format = 'K', array=MaNGA_plate)
col2 = fits.Column(name='MaNGA_IFU', format = 'K', array=MaNGA_IFU)
col3 = fits.Column(name='NSA_plate', format = 'K', array=NSA_plate)
col4 = fits.Column(name='NSA_fiberID', format = 'K', array=NSA_fiberID)
col5 = fits.Column(name='NSA_MJD', format = 'K', array=NSA_MJD)
col6 = fits.Column(name='NSA_index', format = 'K', array=NSA_index)
col7 = fits.Column(name='NSA_ID', format = 'K', array=NSA_ID)
col8 = fits.Column(name='NSA_RA', format = 'D', array=NSA_RA)
col9 = fits.Column(name='NSA_DEC', format = 'D', array=NSA_DEC)
col10 = fits.Column(name='NSA_ba', format = 'D', array=NSA_ba)
col11 = fits.Column(name='NSA_phi', format = 'D', array=NSA_phi)
col12 = fits.Column(name='NSA_redshift', format = 'D', array=NSA_redshift)
col13 = fits.Column(name='NSA_Mstar', format = 'D', array=NSA_Mstar)
col14 = fits.Column(name='smoothness_score', format = 'D', array=smoothness_score)
col15 = fits.Column(name='ba_map', format = 'D', array=ba_map)
col16 = fits.Column(name='ba_err_map', format = 'D', array=ba_err_map)
col17 = fits.Column(name='phi_map', format = 'D', array=phi_map)
col18 = fits.Column(name='phi_err_map', format = 'D', array=phi_err_map)
col19 = fits.Column(name='Vsys_map', format = 'D', array=Vsys_map)
col20 = fits.Column(name='Vsys_err_map', format = 'D', array=Vsys_err_map)
col21 = fits.Column(name='x0_map', format = 'D', array=x0_map)
col22 = fits.Column(name='x0_err_map', format = 'D', array=x0_err_map)
col23 = fits.Column(name='y0_map', format = 'D', array=y0_map)
col24 = fits.Column(name='y0_err_map', format = 'D', array=y0_err_map)
col25 = fits.Column(name='Vmax_map', format = 'D', array=Vmax_map)
col26 = fits.Column(name='Vmax_err_map', format = 'D', array=Vmax_err_map)
col27 = fits.Column(name='alpha_map', format = 'D', array=alpha_map)
col28 = fits.Column(name='alpha_err_map', format = 'D', array=alpha_err_map)
col29 = fits.Column(name='Rturn_map', format = 'D', array=Rturn_map)
col30 = fits.Column(name='Rturn_err_map', format = 'D', array=Rturn_err_map)
col31 = fits.Column(name='M90_map', format = 'D', array=M90_map)
col32 = fits.Column(name='M90_err_map', format = 'D', array=M90_err_map)
col33 = fits.Column(name='M3p5_map', format = 'D', array=M3p5_map)
col34 = fits.Column(name='M3p5_err_map', format = 'D', array=M3p5_err_map)
col35 = fits.Column(name='rho_bulge_map', format = 'D', array=rho_bulge_map)
col36 = fits.Column(name='rho_bulge_err_map', format = 'D', array=rho_bulge_err_map)
col37 = fits.Column(name='R_bulge_map', format = 'D', array=R_bulge_map)
col38 = fits.Column(name='R_bulge_err_map', format = 'D', array=R_bulge_err_map)
col39 = fits.Column(name='M90_disk_map', format = 'D', array=M90_disk_map)
col40 = fits.Column(name='M90_disk_err_map', format = 'D', array=M90_disk_err_map)
col41 = fits.Column(name='M3p5_disk_map', format = 'D', array=M3p5_disk_map)
col42 = fits.Column(name='M3p5_disk_err_map', format = 'D', array=M3p5_disk_err_map)
col43 = fits.Column(name='NSA_elpetro_th90', format = 'D', array=NSA_elpetro_th90)
col44 = fits.Column(name='chi2_map', format = 'D', array=chi2_map)
col45 = fits.Column(name='chi2_disk_map', format = 'D', array=chi2_map)
col46 = fits.Column(name='logHI', format = 'D', array=logHI)
col47 = fits.Column(name='logHI200kms', format = 'D', array=logHI200kms)
col48 = fits.Column(name='WF50', format = 'D', array=WF50)
col49 = fits.Column(name='WF50_err', format = 'D', array=WF50_err)
col50 = fits.Column(name='map_fit_flag', format = 'D', array=map_fit_flag)
col51 = fits.Column(name='DL_ttype', format = 'D', array=DL_ttype)

coldefs = fits.ColDefs([col1, col2, col3, col4, col5, col6, col7, col8, col9, col10, 
                        col11, col12, col13, col14, col15, col16, col17, col18, col19, col20,
                       col21, col22, col23, col24, col25, col26, col27, col28, col29, col30,
                       col31, col32, col33, col34, col35, col36, col37, col38, col39, col40,
                       col41, col42, col43, col44, col45, col46, col47, col48, col49, col50,
                       col51])
hdu = fits.BinTableHDU.from_columns(coldefs)
hdu.writeto('/Users/nityaravi/Documents/Research/RotationCurves/data/manga/' + 'output_files/' + 'master_table_H_alpha_HIvel_BB.fits', overwrite=True)

# %%
w_fn = '/Users/nityaravi/Documents/Research/RotationCurves/data/manga/' + 'output_files/' + 'master_table_H_alpha_HIvel_BB.fits'
w = Table.read(w_fn, format='fits')

# %%
w[0:5]
# Out:
# <Table length=5>
# MaNGA_plate MaNGA_IFU NSA_plate ... map_fit_flag      DL_ttype
#    int64      int64     int64   ...   float64         float64
# ----------- --------- --------- ... ------------ -----------------
#       10001     12701       448 ...          1.5 6.564641952514648
#       10001     12702       448 ...          3.5 4.730921268463135
#       10001     12703       483 ...          2.5 4.756507873535156
#       10001     12704       483 ...          3.5 4.773223400115967
#       10001     12705       484 ...          0.5  4.76101016998291

# %%
#BPT from mpa-jhu galspecextra (updated with dr8)
j_fn = FOLDER + '/manga/galSpecExtra-dr8.fits'
j = Table.read(j_fn, format='fits')

# %%
#BPT = np.ones(len(w))*np.nan
for i in range(0, len(w)):
    if len(j[np.logical_and(j['PLATEID'] == w['NSA_plate'][i], j['FIBERID'] == w['NSA_fiberID'][i], j['MJD'] == w['NSA_MJD'][i])]['BPTCLASS'],
          ) > 1:
        print(i)
# Out:
# 3
# 5
# 9
# 11
# 14
# 187
# 190
# 194
# 197
# 198
# 200
# 203
# 357
# 358
# 362
# 364
# 368
# 369
# 370
# 371
# 372
# 373
# 377
# 379
# 383
# 385
# 386
# 387
# 388
# 390
# 401
# 420

# %%
j
# Out:
# <Table length=1843200>
#      SPECOBJID      PLATEID  MJD  ... SPECSFR_FIB_P97P5 SPECSFR_FIB_ENTROPY
#       bytes19        int32  int32 ...      float32            float32
# ------------------- ------- ----- ... ----------------- -------------------
# 299489676975171584      266 51602 ...        -10.168965          -5.8076763
# 299489951853078528      266 51602 ...        -10.615625           -6.285115
# 299490226730985472      266 51602 ...           -9999.0             -9999.0
# 299490501608892416      266 51602 ...        -10.910714          -6.3215637
# 299490776486799360      266 51602 ...           -9999.0             -9999.0
# 299491051364706304      266 51602 ...         -9.612963          -5.8800097
#                          -1    -1 ...               0.0                 0.0
# 299491601120520192      266 51602 ...        -10.591666          -6.2861195
#                          -1    -1 ...               0.0                 0.0
# ...

# %%
n
# Out:
# <Table length=641409>
#       IAUNAME                  SUBDIR           ... ELPETRO_METS IN_DR7_LSS
#       bytes19                 bytes27           ...   float32     float64
# ------------------- --------------------------- ... ------------ ----------
# J094651.40-010228.5 09h/m00/J094651.40-010228.5 ...  0.025269886        0.0
# J094630.85-004554.5 09h/m00/J094630.85-004554.5 ...  0.027635332        1.0
# J094631.59-005917.7 09h/m00/J094631.59-005917.7 ...  0.021391599        0.0
# J094744.18-004013.4 09h/m00/J094744.18-004013.4 ...  0.027231464        1.0
# J094751.74-003242.0 09h/m00/J094751.74-003242.0 ...  0.025576953        1.0
# J094751.24-004533.5 09h/m00/J094751.24-004533.5 ...  0.021494243        1.0
# J094726.35-004832.0 09h/m00/J094726.35-004832.0 ...   0.03018545        1.0
# J094622.25-004536.9 09h/m00/J094622.25-004536.9 ...   0.02162045        1.0
# J094654.77-003324.5 09h/m00/J094654.77-003324.5 ...   0.02158377        1.0
# ...
