# %%
from astropy.table import Table
import numpy as np
from astropy.io import fits

# %%
m_fn = '/Users/nityaravi/Documents/Research/RotationCurves/data/manga/output_files/DR17/master_table_DR17_noWords.fits'

# %%
m = Table.read(m_fn)

# %%
m
# Out:
# <Table length=11273>
# MaNGA_plate MaNGA_IFU  NSA_ba  ...       DL_ttype       CMD_class
#    int64      int64   float64  ...       float64         float64
# ----------- --------- -------- ... -------------------- ---------
#       10001     12701 0.417013 ...    6.564641952514648   51226.0
#       10001     12702 0.598115 ...    4.730921268463135   51261.0
#       10001     12703 0.378034 ...    4.756507873535156   59078.0
#       10001     12704 0.212315 ...    4.773223400115967   59044.0
#       10001     12705 0.541128 ...     4.76101016998291   59219.0
#       10001      1901 0.532468 ...   1.6820045709609985   58994.0
#       10001      1902 0.839959 ... 0.021545112133026123   51274.0
#       10001      3701 0.907966 ...  -1.1476022005081177   51179.0
#       10001      3702 0.948903 ...  0.09041932225227356   51205.0
#       10001      3703 0.610528 ...    2.792056083679199   59040.0
#         ...       ...      ... ...                  ...       ...
# ...

# %%
m.rename_column('M3p5disk_map', 'M3p5_disk_map')

# %%
m.rename_column('M3p5disk_err_map', 'M3p5_disk_err_map')

# %%
m
# Out:
# <Table length=11273>
# MaNGA_plate MaNGA_IFU  NSA_ba  ...       DL_ttype       CMD_class
#    int64      int64   float64  ...       float64         float64
# ----------- --------- -------- ... -------------------- ---------
#       10001     12701 0.417013 ...    6.564641952514648   51226.0
#       10001     12702 0.598115 ...    4.730921268463135   51261.0
#       10001     12703 0.378034 ...    4.756507873535156   59078.0
#       10001     12704 0.212315 ...    4.773223400115967   59044.0
#       10001     12705 0.541128 ...     4.76101016998291   59219.0
#       10001      1901 0.532468 ...   1.6820045709609985   58994.0
#       10001      1902 0.839959 ... 0.021545112133026123   51274.0
#       10001      3701 0.907966 ...  -1.1476022005081177   51179.0
#       10001      3702 0.948903 ...  0.09041932225227356   51205.0
#       10001      3703 0.610528 ...    2.792056083679199   59040.0
#         ...       ...      ... ...                  ...       ...
# ...

# %%
m.write('/Users/nityaravi/Documents/Research/RotationCurves/data/manga/output_files/DR17/master_table_DR17_noWords.fits',
       overwrite=True)

# %%
m.write('/Users/nityaravi/Documents/Research/RotationCurves/data/manga/output_files/DR17/master_table_DR17_noWords.txt',
        format='ascii.commented_header',
        overwrite=True)
