# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import matplotlib

# %%
matplotlib.rcParams['figure.dpi'] = 100
matplotlib.rcParams['savefig.dpi'] = 300

# %%
images = '/Users/nityaravi/Documents/Research/RotationCurves/data/manga/Images/'

# %%
pic1 = Image.open(images + '/fitted_velocity_fields/7815-3702_fitted_Ha_vel_field.eps')
pic1.load(scale=10)
pic2 = Image.open(images + '/masked_Ha_vel/7815-3702_Ha_vel_field.eps')
pic2.load(scale=10)
pic3 = Image.open(images + '/unmasked_r_band/7815-3702_r_band_raw.eps')
pic3.load(scale=10)
pic4 = Image.open(images + '/vel_map_rot_curve_BB/7815-3702_rot_curve_BB_Ha.eps')
pic4.load(scale=10)

# %%
fig, ax = plt.subplots(2,2, figsize=(15,15))
ax[0,0].imshow(pic1)
ax[0,1].imshow(pic2)
ax[1,0].imshow(pic3)
ax[1,1].imshow(pic4)


ax[0,0].axis('off')
ax[0,1].axis('off')
ax[1,0].axis('off')
ax[1,1].axis('off')


plt.tight_layout()
