# %%
from astropy.table import Table

import numpy as np

import sys
sys.path.insert(1, '/Users/nityaravi/Documents/GitHub/RotationCurves/spirals/')
from extract_HI_functions import calculate_HI_R90

# %%
master_table_folder = '/Users/nityaravi/Documents/Research/RotationCurves/data/manga/output_files/DR17/CURRENT_MASTER_TABLE/'
master_table_fn = master_table_folder + 'H_alpha_HIvel_BB_extinction_H2_MxCG_R90_v3p5_Z_SFR_Portsmouthflux_Zglob.fits'
master_table = Table.read(master_table_fn, format='fits')

# %%
master_table[0:5]
# Out:
# <Table length=5>
# plate ifudsgn   plateifu  mangaid ...  Z_map  Z_err_map M_Z_map M_Z_err_map
# int64 bytes32   bytes32   bytes32 ... float64  float64  float64   float64
# ----- ------- ----------- ------- ... ------- --------- ------- -----------
# 10001   12701 10001-12701 1-48157 ...     0.0       0.0     0.0         0.0
# 10001   12702 10001-12702 1-48188 ...     0.0       0.0     0.0         0.0
# 10001   12703 10001-12703 1-55648 ...     0.0       0.0     0.0         0.0
# 10001   12704 10001-12704 1-55616 ...     0.0       0.0     0.0         0.0
# 10001   12705 10001-12705 1-55784 ...     0.0       0.0     0.0         0.0

# %%
master_table['logMHI_90'] = -999*np.ones(len(master_table))
master_table['logMHI_90_err'] = -999*np.ones(len(master_table))

# %%
for i in range(0, len(master_table)):
    logHI = master_table['logHI'][i]
    R90_kpc = master_table['R90_kpc'][i]
    if logHI > 0 and R90_kpc > 0:
        master_table['logMHI_90'][i], master_table['logMHI_90_err'][i] = calculate_HI_R90(logHI, R90_kpc)

# %%
master_table
# Out:
# <Table length=11273>
# plate ifudsgn   plateifu  ...     logMHI_90         logMHI_90_err
# int64 bytes32   bytes32   ...      float64             float64
# ----- ------- ----------- ... ----------------- ----------------------
# 10001   12701 10001-12701 ...    10.35003923238 1.4164926945700251e-07
# 10001   12702 10001-12702 ... 9.583723595501498 2.0408187920082256e-07
# 10001   12703 10001-12703 ... 9.775858397044264  2.003212762768707e-07
# 10001   12704 10001-12704 ... 9.239541705603026 2.1644130058962535e-07
# 10001   12705 10001-12705 ... 9.864716794532837 1.7433509189183513e-07
# 10001    1901  10001-1901 ...            -999.0                 -999.0
# 10001    1902  10001-1902 ...            -999.0                 -999.0
# 10001    3701  10001-3701 ...            -999.0                 -999.0
# 10001    3702  10001-3702 ...            -999.0                 -999.0
# 10001    3703  10001-3703 ...            -999.0                 -999.0
#   ...     ...         ... ...               ...                    ...
#  9894    3701   9894-3701 ...            -999.0                 -999.0
#  9894    3702   9894-3702 ... 9.672205130999314 1.5858273631051437e-07
#  9894    3703   9894-3703 ...            -999.0                 -999.0
#  9894    3704   9894-3704 ...            -999.0                 -999.0
#  9894    6101   9894-6101 ...            -999.0                 -999.0
#  9894    6102   9894-6102 ...  9.33887399934783 1.4928776309176106e-07
#  9894    6103   9894-6103 ... 9.631711127909401 1.5405548268581922e-07
#  9894    6104   9894-6104 ... 9.723223086791283 1.8217668361044827e-07
#  9894    9101   9894-9101 ...            -999.0                 -999.0
#  9894    9102   9894-9102 ... 9.764639034101778 1.5797432470061287e-07

# %%
Table.write(master_table_folder + 'H_alpha_HIvel_BB_extinction_H2_MxCG_R90_v3p5_Z_SFR_Portsmouthflux_Zglob_HIR90.fits',
           format='fits')
# Out:
# /Users/nityaravi/anaconda3/lib/python3.7/site-packages/astropy/table/column.py:1157: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = getattr(super(), op)(other)
# ---------------------------------------------------------------------------
# IORegistryError                           Traceback (most recent call last)
# <ipython-input-7-cd0a83b15fd7> in <module>
#       1 Table.write(master_table_folder + 'H_alpha_HIvel_BB_extinction_H2_MxCG_R90_v3p5_Z_SFR_Portsmouthflux_Zglob_HIR90.fits',
# ----> 2            format='fits')
#
# ~/anaconda3/lib/python3.7/site-packages/astropy/table/connect.py in __call__(self, serialize_method, *args, **kwargs)
#     125         instance = self._instance
#     126         with serialize_method_as(instance, serialize_method):
# --> 127             registry.write(instance, *args, **kwargs)
#
# ~/anaconda3/lib/python3.7/site-packages/astropy/io/registry.py in write(data, format, *args, **kwargs)
#     567             'write', data.__class__, path, fileobj, args, kwargs)
#     568
# --> 569     writer = get_writer(format, data.__class__)
#     570     writer(data, *args, **kwargs)
#     571
#
# ~/anaconda3/lib/python3.7/site-packages/astropy/io/registry.py in get_writer(data_format, data_class)
#     485             "No writer defined for format '{}' and class '{}'.\n\nThe "
#     486             "available formats are:\n\n{}".format(
# --> 487                 data_format, data_class.__name__, format_table_str))
#     488
#     489
#
# IORegistryError: No writer defined for format 'fits' and class 'NoneType'.
#
# The available formats are:
#
# Format Read Write Auto-identify
# ------ ---- ----- -------------
